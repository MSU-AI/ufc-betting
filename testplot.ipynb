# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
test4 = pd.read_csv('test_4_history.csv')

# %%
test4
# Out:
#             date team opponent bet_side  win_prob  confidence   odds  \
# 0     2021-10-19  LAL      GSW     away  0.500311    0.000623  140.0
# 1     2021-10-20  POR      SAC     away  0.500311    0.000623  220.0
# 2     2021-10-20  NOP      PHI     home  0.499689    0.000623  150.0
# 3     2021-10-20  SAS      ORL     away  0.500311    0.000623  225.0
# 4     2021-10-20  UTA      OKC     away  0.500311    0.000623  750.0
# ...          ...  ...      ...      ...       ...         ...    ...
# 1483  2023-01-16  LAL      HOU     away  0.500311    0.000623  240.0
# 1484  2023-01-16  MIL      IND     away  0.500311    0.000623  175.0
# 1485  2023-01-16  CLE      NOP     away  0.500311    0.000623  250.0
# 1486  2023-01-16  MEM      PHX     away  0.500311    0.000623  550.0
# 1487  2023-01-16  MIN      UTA     away  0.500311    0.000623  155.0
#
#       decimal_odds  kelly_fraction  expected_value  bet_size    won  \
# 0             2.40        0.143391        0.200747  2.867819   True
# ...

# %%
plt.plot(test4.index, test4['bankroll'])
# Add dashed red line from start to end point
plt.plot([test4.index[0], test4.index[-1]], [test4['bankroll'].iloc[0], test4['bankroll'].iloc[-1]], 
         'r--', label='Start to End')
plt.ylabel('Bankroll')
plt.xlabel('Number of Games')
plt.title('Bankroll Over Time')
plt.legend()
plt.show()
